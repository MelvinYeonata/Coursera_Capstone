# %% [markdown]
# ## Final Assignment Capstone Project

# %% [markdown]
# The objective of this project is to determine how many malls are located around Park Central Hotel New York and if it were possible to find out the different kinds of shops in them for the benefit of our stakeholders and hotel customers.
# [Note that I have changed the hotel location due to Foursquare not being able to get coordinates of hotels in other countries.]

# %% [markdown]
# This notebook is used exclusively for the report's methodology section. We will use the combination of Foursquare API and Python to help visualize the data and finally provide a report.

# %% [markdown]
# First, let us start with installing and/or importing the necessary libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata: ...working... done
# Solving environment: ...working...
# Warning: 4 possible package resolutions (only showing differing packages):
#   - anaconda::ca-certificates-2019.1.23-0, anaconda::openssl-1.1.1b-he774522_1
#   - anaconda::openssl-1.1.1b-he774522_1, defaults::ca-certificates-2019.1.23-0
#   - anaconda::ca-certificates-2019.1.23-0, defaults::openssl-1.1.1b-he774522_1
#   - defaults::ca-certificates-2019.1.23-0, defaults::openssl-1.1.1b-he774522_1done
#
# ## Package Plan ##
#
#   environment location: C:\AnacondaDir
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.3.9           |           py37_0         149 KB  conda-forge
#     conda-4.6.14               |           py37_0         2.1 MB  conda-forge
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     geopy-1.19.0               |             py_0          53 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.49-py_0
#   geopy              conda-forge/noarch::geopy-1.19.0-py_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi                                          anaconda --> conda-forge
#   conda                                            anaconda --> conda-forge
#
#
#
# Downloading and Extracting Packages
#
# conda-4.6.14         | 2.1 MB    |            |   0%
# conda-4.6.14         | 2.1 MB    | 1          |   2%
# conda-4.6.14         | 2.1 MB    | 7          |   8%
# conda-4.6.14         | 2.1 MB    | #6         |  17%
# conda-4.6.14         | 2.1 MB    | ##5        |  25%
# conda-4.6.14         | 2.1 MB    | ###4       |  34%
# conda-4.6.14         | 2.1 MB    | ####4      |  44%
# conda-4.6.14         | 2.1 MB    | #####2     |  52%
# conda-4.6.14         | 2.1 MB    | ######2    |  63%
# conda-4.6.14         | 2.1 MB    | #######2   |  73%
# conda-4.6.14         | 2.1 MB    | ########1  |  81%
# conda-4.6.14         | 2.1 MB    | ########9  |  89%
# conda-4.6.14         | 2.1 MB    | #########8 |  99%
# conda-4.6.14         | 2.1 MB    | ########## | 100%
#
# geopy-1.19.0         | 53 KB     |            |   0%
# geopy-1.19.0         | 53 KB     | ########## | 100%
#
# geographiclib-1.49   | 32 KB     |            |   0%
# geographiclib-1.49   | 32 KB     | ########## | 100%
#
# certifi-2019.3.9     | 149 KB    |            |   0%
# certifi-2019.3.9     | 149 KB    | #####6     |  56%
# certifi-2019.3.9     | 149 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting package metadata: ...working... done
# Solving environment: ...working...
# Warning: 4 possible package resolutions (only showing differing packages):
#   - anaconda::ca-certificates-2019.1.23-0, anaconda::openssl-1.1.1b-he774522_1
#   - anaconda::openssl-1.1.1b-he774522_1, defaults::ca-certificates-2019.1.23-0
#   - anaconda::ca-certificates-2019.1.23-0, defaults::openssl-1.1.1b-he774522_1
#   - defaults::ca-certificates-2019.1.23-0, defaults::openssl-1.1.1b-he774522_1done
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %% [markdown]
# Great! Now that we have the necessary library installed and imported, we proceed with defining our Foursquare credentials and version. [Note that I did not show my Client ID and Client Secret for privacy reason]

# %%
# My Foursquare Client ID
CLIENT_ID = ''

# My Foursquare Client Secret
CLIENT_SECRET = ''

# Foursquare Version Tag
VERSION = '20180604'
LIMIT = 30

print('My credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET: ' + CLIENT_SECRET)
# Out:
# My credentials:
# CLIENT_ID: CLIENT_SECRET:

# %% [markdown]
# Now that we have specified our Foursquare Credentials and Version, we proceed in defining the location we work in. That is Park Central Hotel New York. Let us start by identifying the hotel's address as well as its latitude and longitude coordinates.

# %%
# Get address from Google
address = '870 7th Ave, New York, NY 10019, USA'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude) # Show hotel's latitude and longitude coordinates
# Out:
# 40.7646446 -73.9812106

# %% [markdown]
# The coordinates shown above will pin-point the start of our search radius for malls in the area. Let us define a query to search for malls that is within 1 KM radius from the hotel.

# %%
search_query = 'Mall'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# Mall .... OK!

# %% [markdown]
# Now we define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=NIP0GUKEMWDL4YCALJRKCCECHHYJMCNKE4TBVODIMSZV0AMZ&client_secret=K0RRHWZ3WPASICIY2351N5Q5LKQS5DRHCMZFMSHETHJAMI5D&ll=40.7646446,-73.9812106&v=20180604&query=Mall&radius=1000&limit=30'

# %% [markdown]
# Send the GET Request and check the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5cd52ec26a60712128af443b'},
#  'response': {'venues': [{'id': '49ebbf61f964a52020671fe3',
#     'name': 'Central Park Mall',
#     'location': {'address': 'Central Park',
#      'lat': 40.77244937900301,
#      'lng': -73.97154808044434,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.77244937900301,
#        'lng': -73.97154808044434}],
#      'distance': 1190,
#      'postalCode': '10028',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Central Park',
#       'New York, NY 10028',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d163941735',
#       'name': 'Park',
#       'pluralName': 'Parks',
#       'shortName': 'Park',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557475010',
#     'hasPerk': False},
#    {'id': '5716655d498e23619f894ef0',
#     'name': 'TurnStyle Underground Market',
#     'location': {'address': '1000 S 8th Ave',
#      'crossStreet': 'btwn 57th & 58th St',
#      'lat': 40.767081,
#      'lng': -73.982569,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.767081,
#        'lng': -73.982569}],
#      'distance': 294,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1000 S 8th Ave (btwn 57th & 58th St)',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '1104490',
#      'url': 'https://www.seamless.com/menu/taheni-grill-at-turnstyle-1000-8th-ave-new-york/1104490?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1104490',
#      'provider': {'name': 'seamless',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_seamless_20180129.png'}}},
#     'referralId': 'v-1557475010',
#     'hasPerk': False},
#    {'id': '4c2c914957a9c9b65294f767',
#     'name': 'Broadway Pedestrian Mall - 59th St to 53rd St',
#     'location': {'address': 'Broadway',
#      'crossStreet': 'btw Central Park South & 53rd St.',
#      'lat': 40.76690669800086,
#      'lng': -73.9816571000478,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76690669800086,
#        'lng': -73.9816571000478}],
#      'distance': 254,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Broadway (btw Central Park South & 53rd St.)',
#       'New York, NY',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d162941735',
#       'name': 'Other Great Outdoors',
#       'pluralName': 'Other Great Outdoors',
#       'shortName': 'Other Outdoors',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557475010',
#     'hasPerk': False},
#    {'id': '516d8ed1e4b0ffff587a8081',
#     'name': 'Rockefeller Plaza Mall',
#     'location': {'address': '45 Rockefeller Plz',
#      'lat': 40.759151,
#      'lng': -73.977728,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.759151,
#        'lng': -73.977728}],
#      'distance': 678,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['45 Rockefeller Plz',
#       'New York, NY',
#       'United States']},
#     'categories': [{'id': '5744ccdfe4b0c0459246b4dc',
#       'name': 'Shopping Plaza',
#       'pluralName': 'Shopping Plazas',
#       'shortName': 'Shopping Plaza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557475010',
#     'hasPerk': False},
#    {'id': '4c717459b3ce224b48ba76c6',
#     'name': 'Jewel Mall',
#     'location': {'address': '76 W 47th St',
#      'crossStreet': 'at 6th Ave.',
#      'lat': 40.757407417627334,
#      'lng': -73.98189240653575,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.757407417627334,
#        'lng': -73.98189240653575}],
#      'distance': 807,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['76 W 47th St (at 6th Ave.)',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d111951735',
#       'name': 'Jewelry Store',
#       'pluralName': 'Jewelry Stores',
#       'shortName': 'Jewelry',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/jewelry_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557475010',
#     'hasPerk': False},
#    {'id': '4a4971eef964a52058ab1fe3',
#     'name': 'TGI Fridays',
#     'location': {'address': '761 7th Ave',
#      'lat': 40.7611327,
#      'lng': -73.9829467,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7611327,
#        'lng': -73.9829467}],
#      'distance': 417,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['761 7th Ave',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557475010',
#     'hasPerk': False},
#    {'id': '571a5afa498ed30e8208cfc4',
#     'name': 'LUSH',
#     'location': {'address': '1000 South Eighth Avenue, Suite #20',
#      'lat': 40.76869837651813,
#      'lng': -73.98336027116397,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76869837651813,
#        'lng': -73.98336027116397}],
#      'distance': 486,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1000 South Eighth Avenue, Suite #20',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d10c951735',
#       'name': 'Cosmetics Shop',
#       'pluralName': 'Cosmetics Shops',
#       'shortName': 'Cosmetics',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557475010',
#     'hasPerk': False},
#    {'id': '4ba12d0bf964a520169f37e3',
#     'name': 'Literary Walk',
#     'location': {'address': 'The Mall',
#      'crossStreet': 'at East Dr',
#      'lat': 40.76997625932251,
#      'lng': -73.97261766939717,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76997625932251,
#        'lng': -73.97261766939717}],
#      'distance': 936,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['The Mall (at East Dr)',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d166941735',
#       'name': 'Sculpture Garden',
#       'pluralName': 'Sculpture Gardens',
#       'shortName': 'Sculpture',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sculpture_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1557475010',
#     'hasPerk': False}]}}

# %% [markdown]
# Get relevant part of JSON and transform it into a Pandas dataframe

# %%
# Assign relevant part of JSON to venues
venues = results['response']['venues']

# Tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories delivery.id  \
# 0  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...         NaN
# 1  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...     1104490
# 2  [{'id': '4bf58dd8d48988d162941735', 'name': 'O...         NaN
# 3  [{'id': '5744ccdfe4b0c0459246b4dc', 'name': 'S...         NaN
# 4  [{'id': '4bf58dd8d48988d111951735', 'name': 'J...         NaN
#
#                 delivery.provider.icon.name  \
# 0                                       NaN
# 1  /delivery_provider_seamless_20180129.png
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#               delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                                       NaN                          NaN
# 1  https://fastly.4sqi.net/img/general/cap/                     [40, 50]
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
# 4                                       NaN                          NaN
#
#   delivery.provider.name                                       delivery.url  \
# 0                    NaN                                                NaN
# 1               seamless  https://www.seamless.com/menu/taheni-grill-at-...
# 2                    NaN                                                NaN
# 3                    NaN                                                NaN
# 4                    NaN                                                NaN
#
#    hasPerk                        id    location.address  ...  \
# 0    False  49ebbf61f964a52020671fe3        Central Park  ...
# 1    False  5716655d498e23619f894ef0      1000 S 8th Ave  ...
# 2    False  4c2c914957a9c9b65294f767            Broadway  ...
# 3    False  516d8ed1e4b0ffff587a8081  45 Rockefeller Plz  ...
# 4    False  4c717459b3ce224b48ba76c6        76 W 47th St  ...
#
#                 location.crossStreet location.distance  \
# 0                                NaN              1190
# 1                btwn 57th & 58th St               294
# 2  btw Central Park South & 53rd St.               254
# 3                                NaN               678
# 4                        at 6th Ave.               807
#
#                            location.formattedAddress  \
# 0  [Central Park, New York, NY 10028, United States]
# 1  [1000 S 8th Ave (btwn 57th & 58th St), New Yor...
# 2  [Broadway (btw Central Park South & 53rd St.),...
# 3  [45 Rockefeller Plz, New York, NY, United States]
# 4  [76 W 47th St (at 6th Ave.), New York, NY 1003...
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 40.77244937900301...     40.772449
# 1  [{'label': 'display', 'lat': 40.767081, 'lng':...     40.767081
# 2  [{'label': 'display', 'lat': 40.76690669800086...     40.766907
# 3  [{'label': 'display', 'lat': 40.759151, 'lng':...     40.759151
# 4  [{'label': 'display', 'lat': 40.75740741762733...     40.757407
#
#   location.lng location.postalCode  location.state  \
# 0   -73.971548               10028              NY
# 1   -73.982569               10019              NY
# 2   -73.981657                 NaN              NY
# 3   -73.977728                 NaN              NY
# 4   -73.981892               10036              NY
#
#                                             name    referralId
# 0                              Central Park Mall  v-1557475010
# 1                   TurnStyle Underground Market  v-1557475010
# 2  Broadway Pedestrian Mall - 59th St to 53rd St  v-1557475010
# 3                         Rockefeller Plaza Mall  v-1557475010
# 4                                     Jewel Mall  v-1557475010
#
# [5 rows x 23 columns]

# %% [markdown]
# The above dataframe looks very messy and doesn't make much sense to anyone. Let us clean it up a bit and specify information that is of more use and interest for our stakeholder.

# %%
# Keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# Function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# Filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# Clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                             name            categories  \
# 0                              Central Park Mall                  Park
# 1                   TurnStyle Underground Market            Food Court
# 2  Broadway Pedestrian Mall - 59th St to 53rd St  Other Great Outdoors
# 3                         Rockefeller Plaza Mall        Shopping Plaza
# 4                                     Jewel Mall         Jewelry Store
# 5                                    TGI Fridays   American Restaurant
# 6                                           LUSH        Cosmetics Shop
# 7                                  Literary Walk      Sculpture Garden
#
#                                address  cc      city        country  \
# 0                         Central Park  US  New York  United States
# 1                       1000 S 8th Ave  US  New York  United States
# 2                             Broadway  US  New York  United States
# 3                   45 Rockefeller Plz  US  New York  United States
# 4                         76 W 47th St  US  New York  United States
# 5                          761 7th Ave  US  New York  United States
# 6  1000 South Eighth Avenue, Suite #20  US  New York  United States
# 7                             The Mall  US  New York  United States
#
#                          crossStreet  distance  \
# 0                                NaN      1190
# 1                btwn 57th & 58th St       294
# 2  btw Central Park South & 53rd St.       254
# 3                                NaN       678
# 4                        at 6th Ave.       807
# 5                                NaN       417
# 6                                NaN       486
# 7                         at East Dr       936
#
#                                     formattedAddress  \
# 0  [Central Park, New York, NY 10028, United States]
# 1  [1000 S 8th Ave (btwn 57th & 58th St), New Yor...
# 2  [Broadway (btw Central Park South & 53rd St.),...
# 3  [45 Rockefeller Plz, New York, NY, United States]
# 4  [76 W 47th St (at 6th Ave.), New York, NY 1003...
# 5   [761 7th Ave, New York, NY 10019, United States]
# 6  [1000 South Eighth Avenue, Suite #20, New York...
# 7  [The Mall (at East Dr), New York, NY 10022, Un...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 40.77244937900301...  40.772449 -73.971548
# 1  [{'label': 'display', 'lat': 40.767081, 'lng':...  40.767081 -73.982569
# 2  [{'label': 'display', 'lat': 40.76690669800086...  40.766907 -73.981657
# 3  [{'label': 'display', 'lat': 40.759151, 'lng':...  40.759151 -73.977728
# 4  [{'label': 'display', 'lat': 40.75740741762733...  40.757407 -73.981892
# 5  [{'label': 'display', 'lat': 40.7611327, 'lng'...  40.761133 -73.982947
# 6  [{'label': 'display', 'lat': 40.76869837651813...  40.768698 -73.983360
# 7  [{'label': 'display', 'lat': 40.76997625932251...  40.769976 -73.972618
#
#   postalCode state                        id
# 0      10028    NY  49ebbf61f964a52020671fe3
# 1      10019    NY  5716655d498e23619f894ef0
# 2        NaN    NY  4c2c914957a9c9b65294f767
# 3        NaN    NY  516d8ed1e4b0ffff587a8081
# 4      10036    NY  4c717459b3ce224b48ba76c6
# 5      10019    NY  4a4971eef964a52058ab1fe3
# 6      10019    NY  571a5afa498ed30e8208cfc4
# 7      10022    NY  4ba12d0bf964a520169f37e3

# %% [markdown]
# # Show Location in a Map

# %% [markdown]
# This section will visualize the malls that are within 1KM radius of the hotel we work in.

# %%
dataframe_filtered.name
# Out:
# 0                                Central Park Mall
# 1                     TurnStyle Underground Market
# 2    Broadway Pedestrian Mall - 59th St to 53rd St
# 3                           Rockefeller Plaza Mall
# 4                                       Jewel Mall
# 5                                      TGI Fridays
# 6                                             LUSH
# 7                                    Literary Walk
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # Generate map centred around the hotel

# Add a red circle marker to represent the Park Central Hotel New York
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# Add the malls as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# Display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# And there we have it! A map of New York showing the hotel we work in as the red dot and the blue dots are the malls within 1KM radius of our hotel. You can zoom in to get a better and more accurate placements of the dots.

# %% [markdown]
# We can clearly see that there are a total of 8 malls within the 1KM radius of our hotel. The name of malls identified is presented in the dataframe above as well as the mall's category.

# %% [markdown]
# # Explore The Malls!

# %% [markdown]
# Before we begin, I'd like to leave a note that since I'm currently using a sandbox account for Foursquare - I have a very limited number of calls, photos and tips per avenue.

# %% [markdown]
# Let us begin by exploring the first mall nearest to our hotel - Central Park Mall

# %%
venue_id = '49ebbf61f964a52020671fe3' # ID of Central Park Mall from the dataframe
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/49ebbf61f964a52020671fe3?client_id=NIP0GUKEMWDL4YCALJRKCCECHHYJMCNKE4TBVODIMSZV0AMZ&client_secret=K0RRHWZ3WPASICIY2351N5Q5LKQS5DRHCMZFMSHETHJAMI5D&v=20180604'

# %% [markdown]
# Send GET request for result

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'beenHere', 'specials', 'photos', 'reasons', 'page', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'popular', 'pageUpdates', 'inbox', 'parent', 'hierarchy', 'attributes', 'bestPhoto', 'colors'])
# {'id': '49ebbf61f964a52020671fe3',
#  'name': 'Central Park Mall',
#  'contact': {'twitter': 'centralparknyc',
#   'facebook': '37965424481',
#   'facebookUsername': 'centralparknyc',
#   'facebookName': 'Central Park'},
#  'location': {'address': 'Central Park',
#   'lat': 40.77244937900301,
#   'lng': -73.97154808044434,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 40.77244937900301,
#     'lng': -73.97154808044434}],
#   'postalCode': '10028',
#   'cc': 'US',
#   'city': 'New York',
#   'state': 'NY',
#   'country': 'United States',
#   'formattedAddress': ['Central Park', 'New York, NY 10028', 'United States']},
#  'canonicalUrl': 'https://foursquare.com/v/central-park-mall/49ebbf61f964a52020671fe3',
#  'categories': [{'id': '4bf58dd8d48988d163941735',
#    'name': 'Park',
#    'pluralName': 'Parks',
#    'shortName': 'Park',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#     'suffix': '.png'},
#    'primary': True},
#   {'id': '4bf58dd8d48988d15a941735',
#    'name': 'Garden',
#    'pluralName': 'Gardens',
#    'shortName': 'Garden',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#     'suffix': '.png'}}],
#  'verified': True,
#  'stats': {'tipCount': 39},
#  'url': 'http://www.centralparknyc.org',
#  'likes': {'count': 185,
#   'groups': [{'type': 'others', 'count': 185, 'items': []}],
#   'summary': '185 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 9.3,
#  'ratingColor': '00B551',
#  'ratingSignals': 221,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 909,
#   'groups': [{'type': 'checkin',
#     'name': "Friends' check-in photos",
#     'count': 0,
#     'items': []},
#    {'type': 'venue',
#     'name': 'Venue photos',
#     'count': 909,
#     'items': [{'id': '4f91473de4b0fa7ccf84186e',
#       'createdAt': 1334921021,
#       'source': {'name': 'Foursquare for Android',
#        'url': 'https://foursquare.com/download/#/android'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/G8x9JNuwaalv07LlLntB2htupjJIkKRON4mtFU-QTwQ.jpg',
#       'width': 720,
#       'height': 540,
#       'user': {'id': '10323569',
#        'firstName': 'Arwen',
#        'lastName': 'Rosenbaum',
#        'gender': 'none',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/4KXXXLAKCPHQW1WB.jpg'}},
#       'visibility': 'public'}]}],
#   'summary': '0 photos'},
#  'reasons': {'count': 1,
#   'items': [{'summary': 'Lots of people like this place',
#     'type': 'general',
#     'reasonName': 'rawLikesReason'}]},
#  'page': {'pageInfo': {'description': 'The mission of the Central Park Conservancy, a private non-profit, is to restore, manage, and enhance Central Park, in partnership with the public.',
#    'banner': 'https://is1.4sqi.net/userpix/HS2JAA2IAAAR2WZO.jpg',
#    'links': {'count': 1, 'items': [{'url': 'http://www.centralparknyc.org'}]}},
#   'user': {'id': '29060351',
#    'firstName': 'Central Park',
#    'gender': 'none',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/PCPGGJ2N3ULA5O05.jpg'},
#    'type': 'chain',
#    'tips': {'count': 35},
#    'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]},
#    'homeCity': 'New York, NY',
#    'bio': '',
#    'contact': {'twitter': 'centralparknyc', 'facebook': '37965424481'}}},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1240186721,
#  'tips': {'count': 39,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 39,
#     'items': [{'id': '51004136e4b098a6ad96e609',
#       'createdAt': 1358971190,
#       'text': 'Cualquier película que tenga una mínima caminata de sus personajes por Central Park, es en esta callecita. Desde Woody Allen a Encantada de Disney',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/51004136e4b098a6ad96e609',
#       'lang': 'es',
#       'likes': {'count': 6,
#        'groups': [{'type': 'others',
#          'count': 6,
#          'items': [{'id': '3254534',
#            'firstName': 'Bridget',
#            'lastName': 'Hill',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/AH2TCPU3FDCSA5XF.jpg'}},
#           {'id': '782585',
#            'firstName': 'Sir Chandler',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/CCUZYFUQO1OM3OZP.jpg'}},
#           {'id': '41933550',
#            'firstName': 'Damian',
#            'lastName': 'Jure',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/CXLVLZPDJHHMG4B3.jpg'}}]}],
#        'summary': '6 likes'},
#       'logView': True,
#       'agreeCount': 6,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '27550387',
#        'firstName': 'Cines Argentinos',
#        'gender': 'none',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/1HMFUHJREPG4M2BY.png'},
#        'type': 'page'}}]}]},
#  'shortUrl': 'http://4sq.com/8XMmwQ',
#  'timeZone': 'America/New_York',
#  'listed': {'count': 331,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 331,
#     'items': [{'id': '5048954ae4b0756f6721d18a',
#       'name': 'Lugares cinéfilos',
#       'description': 'Lugares en el mundo que cualquier cinéfilo le gustaría conocer. Se van a ir sumando muchos!!',
#       'type': 'others',
#       'user': {'id': '27550387',
#        'firstName': 'Cines Argentinos',
#        'gender': 'none',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/1HMFUHJREPG4M2BY.png'},
#        'type': 'page'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/cinesargentinos/list/lugares-cin%C3%A9filos',
#       'canonicalUrl': 'https://foursquare.com/cinesargentinos/list/lugares-cin%C3%A9filos',
#       'createdAt': 1346934090,
#       'updatedAt': 1403935879,
#       'photo': {'id': '50d7c06eb0edd04fe123d7f1',
#        'createdAt': 1356316782,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/27550387_9BC4dtOwSb4IL0HTKPEN2IImxLAx59d7XTAFn0GbPxA.jpg',
#        'width': 580,
#        'height': 387,
#        'user': {'id': '27550387',
#         'firstName': 'Cines Argentinos',
#         'gender': 'none',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/1HMFUHJREPG4M2BY.png'},
#         'type': 'page'},
#        'visibility': 'public'},
#       'logView': True,
#       'followers': {'count': 57},
#       'listItems': {'count': 31,
#        'items': [{'id': 't51004136e4b098a6ad96e609',
#          'createdAt': 1358970555,
#          'photo': {'id': '4e395463814d9fd8faf6b2fd',
#           'createdAt': 1312380003,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/L5252JMLV3DKNXSM13WWGNUABFH3QRVXKMKKVW4LHWPIIHWO.jpg',
#           'width': 480,
#           'height': 320,
#           'user': {'id': '95423',
#            'firstName': 'The Corcoran Group',
#            'gender': 'none',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/95423-FGRZ1IMU5FZQMCZB.jpg'},
#            'type': 'page'},
#           'visibility': 'public'}}]}},
#      {'id': '4fad24a2e4b0bcc0c18be03c',
#       'name': '101 places to see in Manhattan before you die',
#       'description': 'Best spots to see in Manhattan (New York City) as restaurants, monuments and public spaces. Enjoy!',
#       'type': 'others',
#       'user': {'id': '356747',
#        'firstName': 'Victor',
#        'lastName': 'Garrido',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/356747-WQOTM2ASOIERONL3.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/boke/list/101-places-to-see-in-manhattan-before-you-die',
#       'canonicalUrl': 'https://foursquare.com/boke/list/101-places-to-see-in-manhattan-before-you-die',
#       'createdAt': 1336747170,
#       'updatedAt': 1406242886,
#       'photo': {'id': '4fa97b0c121d8a3faef6f2df',
#        'createdAt': 1336507148,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/IcmBihQCVr4Zt0Vxt9l237NHv--nxg1Z5_8QIMjeD8E.jpg',
#        'width': 325,
#        'height': 487,
#        'user': {'id': '13125997',
#         'firstName': 'IWalked Audio Tours',
#         'gender': 'none',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/KZCTVBJ0FXUHSQA5.jpg'},
#         'type': 'page'},
#        'visibility': 'public'},
#       'followers': {'count': 949},
#       'listItems': {'count': 101,
#        'items': [{'id': 't4e04a0cdcc3fa8142b5c1746',
#          'createdAt': 1336747670,
#          'photo': {'id': '4fa6aa14e4b05ddd67ff24ac',
#           'createdAt': 1336322580,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/_VVVMzrJEWpj-bRs0oXA9NcIGu7Xb2RzuqUREjFsveA.jpg',
#           'width': 720,
#           'height': 540,
#           'user': {'id': '1770449',
#            'firstName': 'Stephane',
#            'lastName': 'Cohen',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/YWQP50FCGSTXT2QD.jpg'}},
#           'visibility': 'public'}}]}},
#      {'id': '4f591ff9e4b063a4ac63e812',
#       'name': 'Tri-State Area (NY-NJ-CT)',
#       'description': "NYC isn't just Manhattan, but also includes Queens, Brooklyn, Staten Island and the Bronx. However, most people working in NYC stay in the Tri-State Area, be they Connecticut or Long Island.",
#       'type': 'others',
#       'user': {'id': '3600455',
#        'firstName': 'Jeremy',
#        'lastName': 'Ong',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/QH4TMTOZ3FGZRNTU.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/jeremyscong/list/tristate-area-nynjct',
#       'canonicalUrl': 'https://foursquare.com/jeremyscong/list/tristate-area-nynjct',
#       'createdAt': 1331240953,
#       'updatedAt': 1423448001,
#       'followers': {'count': 63},
#       'listItems': {'count': 198,
#        'items': [{'id': 'v49ebbf61f964a52020671fe3',
#          'createdAt': 1331242017}]}}]}]},
#  'popular': {'isOpen': False,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '7:00 AM–8:00 AM'},
#      {'renderedTime': '1:00 PM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '8:00 AM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '7:00 AM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': '7:00 AM–8:00 AM'},
#      {'renderedTime': 'Noon–7:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '1:00 PM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Wed',
#     'open': [{'renderedTime': '7:00 AM–8:00 AM'},
#      {'renderedTime': '1:00 PM–4:00 PM'}],
#     'segments': []},
#    {'days': 'Thu',
#     'open': [{'renderedTime': 'Noon–5:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 2, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'parent': {'id': '412d2800f964a520df0c1fe3',
#   'name': 'Central Park',
#   'location': {'address': '59th St to 110th St',
#    'crossStreet': '5th Ave to Central Park West',
#    'lat': 40.78408342593807,
#    'lng': -73.96485328674316,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.78408342593807,
#      'lng': -73.96485328674316}],
#    'postalCode': '10028',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['59th St to 110th St (5th Ave to Central Park West)',
#     'New York, NY 10028',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d163941735',
#     'name': 'Park',
#     'pluralName': 'Parks',
#     'shortName': 'Park',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#      'suffix': '.png'},
#     'primary': True}]},
#  'hierarchy': [{'name': 'Central Park',
#    'lang': 'en',
#    'id': '412d2800f964a520df0c1fe3',
#    'canonicalUrl': 'https://foursquare.com/v/central-park/412d2800f964a520df0c1fe3'}],
#  'attributes': {'groups': []},
#  'bestPhoto': {'id': '4f91473de4b0fa7ccf84186e',
#   'createdAt': 1334921021,
#   'source': {'name': 'Foursquare for Android',
#    'url': 'https://foursquare.com/download/#/android'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/G8x9JNuwaalv07LlLntB2htupjJIkKRON4mtFU-QTwQ.jpg',
#   'width': 720,
#   'height': 540,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '4f91473de4b0fa7ccf84186e',
#    'value': -14669808},
#   'highlightTextColor': {'photoId': '4f91473de4b0fa7ccf84186e', 'value': -1},
#   'algoVersion': 3}}

# %% [markdown]
# Get the mall's overall rating

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 9.3

# %% [markdown]
# This is a great rating out of 10! Let's delve in deeper and get the number of tips for the mall.

# %%
result['response']['venue']['tips']['count']
# Out:
# 39

# %% [markdown]
# There are 39 number of tips for Central Park Mall. This is surely a popular place for shopping!

# %% [markdown]
# Let's get the tips:

# %%
## Central Park Mall Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5cd53a956a607121273bfbe3'},
#  'response': {'tips': {'count': 39,
#    'items': [{'id': '5b0a9a189ba3e5002c434257',
#      'createdAt': 1527421464,
#      'text': "Another highly photographed part of Central Park, with beautiful trees lining the pathway. At the Southern end you'll find the LITERARY WALK, with statues of several literary figures",
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/5b0a9a189ba3e5002c434257',
#      'lang': 'en',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'agreeCount': 3,
#      'disagreeCount': 0,
#      'lastVoteText': 'Upvoted Feb 21',
#      'lastUpvoteTimestamp': 1550774769,
#      'todo': {'count': 0},
#      'user': {'id': '2787312',
#       'firstName': 'May',
#       'lastName': '♍',
#       'gender': 'female',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/2787312_8D9r3Ylr_VFZy1eJqtnSoh791MVQf5RV7z9JLJ0TCW7xS8xFd6S3P8xwurGvQmvbSv0K3IhQX.jpg'}},
#      'authorInteractionType': 'liked'}]}}}

# %% [markdown]
# The result is a bit messy... Let's clean it up a bit

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'lastVoteText', 'lastUpvoteTimestamp', 'todo', 'user', 'authorInteractionType'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
#                                                                                                                                                                                      text  \
# 0  Another highly photographed part of Central Park, with beautiful trees lining the pathway. At the Southern end you'll find the LITERARY WALK, with statues of several literary figures
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  3           0              5b0a9a189ba3e5002c434257  May
#
#   user.lastName user.gender  user.id
# 0  ♍             female      2787312

# %% [markdown]
# Unfortunately, since we are using a sandbox account, we get only 1 tip per avenue. We can do this for all the malls we have identified within 1KM radius of our hotel by repeating the process for each one of them but that would mean upgrading the Foursquare account beyond developer's account.

# %% [markdown]
# # Explore Trending Malls

# %% [markdown]
# For the final part, let us explore the trending malls around Central Park Mall.

# %%
# Define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# Send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5cd53d399fb6b756b16f7ad8'},
#  'response': {'venues': []}}

# %% [markdown]
# Check if any venues are trending at this time:

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # Filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # Filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# Display trending venues
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %% [markdown]
# Oops! There are none available at the moment. This result occur because such information are fetched live and there are none at the moment. Since there are none, we cannot proceed to visualize the trending venues which brings us to the end of our methodology stage for the project report.
